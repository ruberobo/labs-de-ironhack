# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x,y,lw=1,color="y", ls='--')
plt.legend(['x=y'])
plt.subplot(1,2,2)
plt.plot(x,z,lw=1, color="g",ls='-')
plt.legend(['y=x^2'])
plt.show;

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig,graficas=plt.subplots(1,2)
graficas[0].plot(x,y,color="black", lw=1, ls='--')
graficas[0].legend(['y=x'])
graficas[1].plot(x,z,color="pink", lw=1, ls='-')
graficas[1].legend(['y=x*x'])

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, graficas = plt.subplots(nrows=1, ncols=2,figsize=(15,5))

graficas[0].plot(x,y,color="purple", lw=1)
graficas[1].plot(x,z,color="silver", lw=2, ls='--')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, graficas = plt.subplots(nrows=1, ncols=2,figsize=(15,5))

graficas[0].plot(x,y,color="purple", lw=1)
graficas[0].set_xlabel('x')
graficas[0].set_ylabel('y=x')


graficas[1].plot(x,z,color="silver", lw=2, ls='--')
graficas[1].set_xlabel('x')
graficas[1].set_ylabel('z=x^2')
# Out:
# Text(0, 0.5, 'z=x^2')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, graficas = plt.subplots(1, 2, figsize=(16,4))
      
graficas[0].plot(x, x**2,x, np.exp(x))
graficas[0].set_title("Normal scale")
graficas[0].legend(['x*x','exp(x)'])

graficas[1].plot(x, x**2,x, np.exp(x))
graficas[1].set_yscale("log")
graficas[1].set_title("log scale")
graficas[1].legend(['x*x','exp(x)'])

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
import pandas as pd
data = pd.read_csv('/Users/rube/datamex_082020/module-2/lab-matplotlib-seaborn/your-code/vehicles.csv')

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
x = data['Combined MPG']
y=data['Highway MPG']

# %%
plt.scatter(x,y, lw=0.1)
plt.show();

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
data['CO2 Emission Grams/Mile'].plot(kind = 'box', title='CO2 emissions g/mile')
# Out:
# <AxesSubplot:title={'center':'CO2 emissions g/mile'}>

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
data['Fuel Barrels/Year'].plot(kind = 'hist', bins =50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
fuel = data.groupby('Fuel Type')['City MPG'].agg('sum')

# %%
x = data['Fuel Type']
y = data['City MPG']

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 35952 artists>

# %%
#grafica bonita
fig, grafica = plt.subplots(figsize=(15,5))
grafica.bar(x,y)
plt.xticks(rotation=90)
plt.show();
