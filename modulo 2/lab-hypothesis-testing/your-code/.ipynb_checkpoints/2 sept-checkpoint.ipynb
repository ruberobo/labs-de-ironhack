# %%
import pandas as pd

# %% [markdown]
# # ANOVA (análisis de varianza)
# supuestos
# La variable dependiente debe ser continua
# La variable dependiente se distribuye normalmente en cada grupo
# Homogeneidad de varianzas
# Las observaciones son independientes
# **No debemos tener outliers

# %%
rate = pd.read_csv('/Users/rube/Downloads/rate_by_city.csv')

# %%
rate['city_count'] = rate.groupby('City').cumcount()
rate
# Out:
#      Rate  City  city_count
# 0   13.75     1           0
# 1   13.75     1           1
# 2   13.50     1           2
# 3   13.50     1           3
# 4   13.00     1           4
# 5   13.00     1           5
# 6   13.00     1           6
# 7   12.75     1           7
# 8   12.50     1           8
# 9   14.25     2           0
# 10  13.00     2           1
# 11  12.75     2           2
# 12  12.50     2           3
# 13  12.50     2           4
# 14  12.40     2           5
# 15  12.30     2           6
# 16  11.90     2           7
# 17  11.90     2           8
# 18  14.00     3           0
# 19  14.00     3           1
# 20  13.51     3           2
# 21  13.50     3           3
# 22  13.50     3           4
# 23  13.25     3           5
# 24  13.00     3           6
# 25  12.50     3           7
# 26  12.50     3           8
# 27  15.00     4           0
# 28  14.00     4           1
# 29  13.75     4           2
# 30  13.59     4           3
# 31  13.25     4           4
# 32  12.97     4           5
# 33  12.50     4           6
# 34  12.25     4           7
# 35  11.89     4           8
# 36  14.50     5           0
# 37  14.00     5           1
# 38  14.00     5           2
# 39  13.90     5           3
# 40  13.75     5           4
# 41  13.25     5           5
# 42  13.00     5           6
# 43  12.50     5           7
# 44  12.45     5           8
# 45  13.50     6           0
# 46  12.25     6           1
# 47  12.25     6           2
# 48  12.00     6           3
# 49  12.00     6           4
# 50  12.00     6           5
# 51  12.00     6           6
# 52  11.90     6           7
# 53  11.90     6           8

# %%
df = pd.read_csv('/Users/rube/Downloads/USA_Housing.csv')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 4                             4.23     26354.109472  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df[df.columns[0]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11dd0d210>,
#   <matplotlib.lines.Line2D at 0x11dd68910>],
#  'caps': [<matplotlib.lines.Line2D at 0x11dd68d50>,
#   <matplotlib.lines.Line2D at 0x11dd771d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11dc99910>],
#  'medians': [<matplotlib.lines.Line2D at 0x11dd77650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11dd77a90>],
#  'means': []}

# %%
plt.boxplot(df[df.columns[1]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11de5f7d0>,
#   <matplotlib.lines.Line2D at 0x11de5fc10>],
#  'caps': [<matplotlib.lines.Line2D at 0x11de6b090>,
#   <matplotlib.lines.Line2D at 0x11de6b4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11de5f3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11de6b950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11de6bd90>],
#  'means': []}

# %%
plt.boxplot(df['Area Population'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11e1bc850>,
#   <matplotlib.lines.Line2D at 0x11e1cbbd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e1cb890>,
#   <matplotlib.lines.Line2D at 0x11dde9c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11e1bce50>],
#  'medians': [<matplotlib.lines.Line2D at 0x11de963d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11de96c10>],
#  'means': []}

# %%
quant_20 =df['Area Population'].quantile(0.20)
quant_80 =df['Area Population'].quantile(0.80)

# %%
df_2 = df[(df['Area Population']>=quant_20) &(df['Area Population']<=quant_80)]

# %%
df_2.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       3000.000000          3000.000000                3000.000000
# mean       68607.490870             5.977713                   6.978458
# std        10599.783187             0.983757                   1.005495
# min        37908.675863             2.797619                   3.950225
# 25%        61470.496877             5.323276                   6.297549
# 50%        68740.293014             5.966585                   6.990668
# 75%        75742.557222             6.632183                   7.654167
# max       107701.748378             9.125283                  10.280022
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   3000.000000      3000.000000  3.000000e+03
# mean                       4.002810     36143.982199  1.231739e+06
# std                        1.232755      4623.428041  3.302244e+05
# min                        2.000000     27721.393641  3.114052e+04
# 25%                        3.150000     32312.725709  1.015863e+06
# 50%                        4.060000     36199.406689  1.231994e+06
# 75%                        4.500000     40081.126950  1.454151e+06
# max                        6.500000     44381.267536  2.469066e+06

# %%
plt.boxplot(df_2['Area Population'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11dee8c10>,
#   <matplotlib.lines.Line2D at 0x11def0090>],
#  'caps': [<matplotlib.lines.Line2D at 0x11def04d0>,
#   <matplotlib.lines.Line2D at 0x11def0910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11dee8810>],
#  'medians': [<matplotlib.lines.Line2D at 0x11def0d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11defb210>],
#  'means': []}

# %%
quant_20_i =df_2['Avg. Area Income'].quantile(0.20)
quant_80_i =df_2['Avg. Area Income'].quantile(0.80)

# %%
df_2 = df_2[(df_2['Avg. Area Income']>=quant_20_i)&(df_2['Avg. Area Income']<=quant_80_i)]

# %%
df_2
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 8         59927.660813             5.362126                   6.393121
# 13        73163.663441             6.919535                   5.993188
# 14        69391.380184             5.344776                   8.406418
# ...                ...                  ...                        ...
# 4985      75117.042949             6.036275                   6.538111
# 4986      71060.406015             5.718839                   7.222730
# 4988      67637.840665             7.056673                   5.774409
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 8                             2.30     29387.396003  7.988695e+05
# 13                            2.27     32326.123139  1.291332e+06
# 14                            4.37     35521.294033  1.402818e+06
# ...                            ...              ...           ...
# 4985                          2.22     43976.031060  1.378938e+06
# 4986                          4.34     34814.585591  1.260241e+06
# 4988                          3.05     43846.531340  1.275143e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
#
#                                                 Address
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 8                             USS Gilbert\nFPO AA 20957
# 13    829 Welch Track Apt. 992\nNorth John, AR 26532...
# 14                     PSC 5330, Box 4420\nAPO AP 08302
# ...                                                 ...
# 4985                   PSC 7442, Box 6234\nAPO AP 13017
# 4986     5611 Matthew Avenue\nLake Kevin, FM 72963-8891
# 4988  6066 Sanders Court Apt. 914\nSouth Alexis, FM ...
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
#
# [1800 rows x 7 columns]
