# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **pokemons**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
pokemon = pd.read_csv('/Users/rube/datamex_082020/module-2/lab-df-calculation-and-transformation/your-code/Pokemon.csv')

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Obtain the distinct values across `Type 1` and `Type 2`
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# enter your code here
tipos = pokemon[['Type 1','Type 2']].to_records()
tipos
# Out:
# rec.array([(  0, 'Grass', 'Poison'), (  1, 'Grass', 'Poison'),
#            (  2, 'Grass', 'Poison'), (  3, 'Grass', 'Poison'),
#            (  4, 'Fire', nan), (  5, 'Fire', nan),
#            (  6, 'Fire', 'Flying'), (  7, 'Fire', 'Dragon'),
#            (  8, 'Fire', 'Flying'), (  9, 'Water', nan),
#            ( 10, 'Water', nan), ( 11, 'Water', nan), ( 12, 'Water', nan),
#            ( 13, 'Bug', nan), ( 14, 'Bug', nan), ( 15, 'Bug', 'Flying'),
#            ( 16, 'Bug', 'Poison'), ( 17, 'Bug', 'Poison'),
#            ( 18, 'Bug', 'Poison'), ( 19, 'Bug', 'Poison'),
#            ( 20, 'Normal', 'Flying'), ( 21, 'Normal', 'Flying'),
#            ( 22, 'Normal', 'Flying'), ( 23, 'Normal', 'Flying'),
#            ( 24, 'Normal', nan), ( 25, 'Normal', nan),
#            ( 26, 'Normal', 'Flying'), ( 27, 'Normal', 'Flying'),
#            ( 28, 'Poison', nan), ( 29, 'Poison', nan),
#            ( 30, 'Electric', nan), ( 31, 'Electric', nan),
#            ( 32, 'Ground', nan), ( 33, 'Ground', nan),
#            ( 34, 'Poison', nan), ( 35, 'Poison', nan),
#            ( 36, 'Poison', 'Ground'), ( 37, 'Poison', nan),
#            ( 38, 'Poison', nan), ( 39, 'Poison', 'Ground'),
#            ( 40, 'Fairy', nan), ( 41, 'Fairy', nan), ( 42, 'Fire', nan),
#            ( 43, 'Fire', nan), ( 44, 'Normal', 'Fairy'),
#            ( 45, 'Normal', 'Fairy'), ( 46, 'Poison', 'Flying'),
#            ( 47, 'Poison', 'Flying'), ( 48, 'Grass', 'Poison'),
#            ( 49, 'Grass', 'Poison'), ( 50, 'Grass', 'Poison'),
#            ( 51, 'Bug', 'Grass'), ( 52, 'Bug', 'Grass'),
#            ( 53, 'Bug', 'Poison'), ( 54, 'Bug', 'Poison'),
#            ( 55, 'Ground', nan), ( 56, 'Ground', nan),
#            ( 57, 'Normal', nan), ( 58, 'Normal', nan),
#            ( 59, 'Water', nan), ( 60, 'Water', nan),
#            ( 61, 'Fighting', nan), ( 62, 'Fighting', nan),
#            ( 63, 'Fire', nan), ( 64, 'Fire', nan), ( 65, 'Water', nan),
#            ( 66, 'Water', nan), ( 67, 'Water', 'Fighting'),
#            ( 68, 'Psychic', nan), ( 69, 'Psychic', nan),
#            ( 70, 'Psychic', nan), ( 71, 'Psychic', nan),
#            ( 72, 'Fighting', nan), ( 73, 'Fighting', nan),
#            ( 74, 'Fighting', nan), ( 75, 'Grass', 'Poison'),
#            ( 76, 'Grass', 'Poison'), ( 77, 'Grass', 'Poison'),
#            ( 78, 'Water', 'Poison'), ( 79, 'Water', 'Poison'),
#            ( 80, 'Rock', 'Ground'), ( 81, 'Rock', 'Ground'),
#            ( 82, 'Rock', 'Ground'), ( 83, 'Fire', nan),
#            ( 84, 'Fire', nan), ( 85, 'Water', 'Psychic'),
#            ( 86, 'Water', 'Psychic'), ( 87, 'Water', 'Psychic'),
#            ( 88, 'Electric', 'Steel'), ( 89, 'Electric', 'Steel'),
#            ( 90, 'Normal', 'Flying'), ( 91, 'Normal', 'Flying'),
#            ( 92, 'Normal', 'Flying'), ( 93, 'Water', nan),
#            ( 94, 'Water', 'Ice'), ( 95, 'Poison', nan),
#            ( 96, 'Poison', nan), ( 97, 'Water', nan),
#            ( 98, 'Water', 'Ice'), ( 99, 'Ghost', 'Poison'),
#            (100, 'Ghost', 'Poison'), (101, 'Ghost', 'Poison'),
#            (102, 'Ghost', 'Poison'), (103, 'Rock', 'Ground'),
#            (104, 'Psychic', nan), (105, 'Psychic', nan),
#            (106, 'Water', nan), (107, 'Water', nan),
#            (108, 'Electric', nan), (109, 'Electric', nan),
#            (110, 'Grass', 'Psychic'), (111, 'Grass', 'Psychic'),
#            (112, 'Ground', nan), (113, 'Ground', nan),
#            (114, 'Fighting', nan), (115, 'Fighting', nan),
#            (116, 'Normal', nan), (117, 'Poison', nan),
#            (118, 'Poison', nan), (119, 'Ground', 'Rock'),
#            (120, 'Ground', 'Rock'), (121, 'Normal', nan),
#            (122, 'Grass', nan), (123, 'Normal', nan),
#            (124, 'Normal', nan), (125, 'Water', nan), (126, 'Water', nan),
#            (127, 'Water', nan), (128, 'Water', nan), (129, 'Water', nan),
#            (130, 'Water', 'Psychic'), (131, 'Psychic', 'Fairy'),
#            (132, 'Bug', 'Flying'), (133, 'Ice', 'Psychic'),
#            (134, 'Electric', nan), (135, 'Fire', nan), (136, 'Bug', nan),
#            (137, 'Bug', 'Flying'), (138, 'Normal', nan),
#            (139, 'Water', nan), (140, 'Water', 'Flying'),
#            (141, 'Water', 'Dark'), (142, 'Water', 'Ice'),
#            (143, 'Normal', nan), (144, 'Normal', nan),
#            (145, 'Water', nan), (146, 'Electric', nan),
#            (147, 'Fire', nan), (148, 'Normal', nan),
#            (149, 'Rock', 'Water'), (150, 'Rock', 'Water'),
#            (151, 'Rock', 'Water'), (152, 'Rock', 'Water'),
#            (153, 'Rock', 'Flying'), (154, 'Rock', 'Flying'),
#            (155, 'Normal', nan), (156, 'Ice', 'Flying'),
#            (157, 'Electric', 'Flying'), (158, 'Fire', 'Flying'),
#            (159, 'Dragon', nan), (160, 'Dragon', nan),
#            (161, 'Dragon', 'Flying'), (162, 'Psychic', nan),
#            (163, 'Psychic', 'Fighting'), (164, 'Psychic', nan),
#            (165, 'Psychic', nan), (166, 'Grass', nan),
#            (167, 'Grass', nan), (168, 'Grass', nan), (169, 'Fire', nan),
#            (170, 'Fire', nan), (171, 'Fire', nan), (172, 'Water', nan),
#            (173, 'Water', nan), (174, 'Water', nan), (175, 'Normal', nan),
#            (176, 'Normal', nan), (177, 'Normal', 'Flying'),
#            (178, 'Normal', 'Flying'), (179, 'Bug', 'Flying'),
#            (180, 'Bug', 'Flying'), (181, 'Bug', 'Poison'),
#            (182, 'Bug', 'Poison'), (183, 'Poison', 'Flying'),
#            (184, 'Water', 'Electric'), (185, 'Water', 'Electric'),
#            (186, 'Electric', nan), (187, 'Fairy', nan),
#            (188, 'Normal', 'Fairy'), (189, 'Fairy', nan),
#            (190, 'Fairy', 'Flying'), (191, 'Psychic', 'Flying'),
#            (192, 'Psychic', 'Flying'), (193, 'Electric', nan),
#            (194, 'Electric', nan), (195, 'Electric', nan),
#            (196, 'Electric', 'Dragon'), (197, 'Grass', nan),
#            (198, 'Water', 'Fairy'), (199, 'Water', 'Fairy'),
#            (200, 'Rock', nan), (201, 'Water', nan),
#            (202, 'Grass', 'Flying'), (203, 'Grass', 'Flying'),
#            (204, 'Grass', 'Flying'), (205, 'Normal', nan),
#            (206, 'Grass', nan), (207, 'Grass', nan),
#            (208, 'Bug', 'Flying'), (209, 'Water', 'Ground'),
#            (210, 'Water', 'Ground'), (211, 'Psychic', nan),
#            (212, 'Dark', nan), (213, 'Dark', 'Flying'),
#            (214, 'Water', 'Psychic'), (215, 'Ghost', nan),
#            (216, 'Psychic', nan), (217, 'Psychic', nan),
#            (218, 'Normal', 'Psychic'), (219, 'Bug', nan),
#            (220, 'Bug', 'Steel'), (221, 'Normal', nan),
#            (222, 'Ground', 'Flying'), (223, 'Steel', 'Ground'),
#            (224, 'Steel', 'Ground'), (225, 'Fairy', nan),
#            (226, 'Fairy', nan), (227, 'Water', 'Poison'),
#            (228, 'Bug', 'Steel'), (229, 'Bug', 'Steel'),
#            (230, 'Bug', 'Rock'), (231, 'Bug', 'Fighting'),
#            (232, 'Bug', 'Fighting'), (233, 'Dark', 'Ice'),
#            (234, 'Normal', nan), (235, 'Normal', nan), (236, 'Fire', nan),
#            (237, 'Fire', 'Rock'), (238, 'Ice', 'Ground'),
#            (239, 'Ice', 'Ground'), (240, 'Water', 'Rock'),
#            (241, 'Water', nan), (242, 'Water', nan),
#            (243, 'Ice', 'Flying'), (244, 'Water', 'Flying'),
#            (245, 'Steel', 'Flying'), (246, 'Dark', 'Fire'),
#            (247, 'Dark', 'Fire'), (248, 'Dark', 'Fire'),
#            (249, 'Water', 'Dragon'), (250, 'Ground', nan),
#            (251, 'Ground', nan), (252, 'Normal', nan),
#            (253, 'Normal', nan), (254, 'Normal', nan),
#            (255, 'Fighting', nan), (256, 'Fighting', nan),
#            (257, 'Ice', 'Psychic'), (258, 'Electric', nan),
#            (259, 'Fire', nan), (260, 'Normal', nan), (261, 'Normal', nan),
#            (262, 'Electric', nan), (263, 'Fire', nan),
#            (264, 'Water', nan), (265, 'Rock', 'Ground'),
#            (266, 'Rock', 'Ground'), (267, 'Rock', 'Dark'),
#            (268, 'Rock', 'Dark'), (269, 'Psychic', 'Flying'),
#            (270, 'Fire', 'Flying'), (271, 'Psychic', 'Grass'),
#            (272, 'Grass', nan), (273, 'Grass', nan), (274, 'Grass', nan),
#            (275, 'Grass', 'Dragon'), (276, 'Fire', nan),
#            (277, 'Fire', 'Fighting'), (278, 'Fire', 'Fighting'),
#            (279, 'Fire', 'Fighting'), (280, 'Water', nan),
#            (281, 'Water', 'Ground'), (282, 'Water', 'Ground'),
#            (283, 'Water', 'Ground'), (284, 'Dark', nan),
#            (285, 'Dark', nan), (286, 'Normal', nan), (287, 'Normal', nan),
#            (288, 'Bug', nan), (289, 'Bug', nan), (290, 'Bug', 'Flying'),
#            (291, 'Bug', nan), (292, 'Bug', 'Poison'),
#            (293, 'Water', 'Grass'), (294, 'Water', 'Grass'),
#            (295, 'Water', 'Grass'), (296, 'Grass', nan),
#            (297, 'Grass', 'Dark'), (298, 'Grass', 'Dark'),
#            (299, 'Normal', 'Flying'), (300, 'Normal', 'Flying'),
#            (301, 'Water', 'Flying'), (302, 'Water', 'Flying'),
#            (303, 'Psychic', 'Fairy'), (304, 'Psychic', 'Fairy'),
#            (305, 'Psychic', 'Fairy'), (306, 'Psychic', 'Fairy'),
#            (307, 'Bug', 'Water'), (308, 'Bug', 'Flying'),
#            (309, 'Grass', nan), (310, 'Grass', 'Fighting'),
#            (311, 'Normal', nan), (312, 'Normal', nan),
#            (313, 'Normal', nan), (314, 'Bug', 'Ground'),
#            (315, 'Bug', 'Flying'), (316, 'Bug', 'Ghost'),
#            (317, 'Normal', nan), (318, 'Normal', nan),
#            (319, 'Normal', nan), (320, 'Fighting', nan),
#            (321, 'Fighting', nan), (322, 'Normal', 'Fairy'),
#            (323, 'Rock', nan), (324, 'Normal', nan), (325, 'Normal', nan),
#            (326, 'Dark', 'Ghost'), (327, 'Dark', 'Ghost'),
#            (328, 'Steel', 'Fairy'), (329, 'Steel', 'Fairy'),
#            (330, 'Steel', 'Rock'), (331, 'Steel', 'Rock'),
#            (332, 'Steel', 'Rock'), (333, 'Steel', nan),
#            (334, 'Fighting', 'Psychic'), (335, 'Fighting', 'Psychic'),
#            (336, 'Fighting', 'Psychic'), (337, 'Electric', nan),
#            (338, 'Electric', nan), (339, 'Electric', nan),
#            (340, 'Electric', nan), (341, 'Electric', nan),
#            (342, 'Bug', nan), (343, 'Bug', nan), (344, 'Grass', 'Poison'),
#            (345, 'Poison', nan), (346, 'Poison', nan),
#            (347, 'Water', 'Dark'), (348, 'Water', 'Dark'),
#            (349, 'Water', 'Dark'), (350, 'Water', nan),
#            (351, 'Water', nan), (352, 'Fire', 'Ground'),
#            (353, 'Fire', 'Ground'), (354, 'Fire', 'Ground'),
#            (355, 'Fire', nan), (356, 'Psychic', nan),
#            (357, 'Psychic', nan), (358, 'Normal', nan),
#            (359, 'Ground', nan), (360, 'Ground', 'Dragon'),
#            (361, 'Ground', 'Dragon'), (362, 'Grass', nan),
#            (363, 'Grass', 'Dark'), (364, 'Normal', 'Flying'),
#            (365, 'Dragon', 'Flying'), (366, 'Dragon', 'Fairy'),
#            (367, 'Normal', nan), (368, 'Poison', nan),
#            (369, 'Rock', 'Psychic'), (370, 'Rock', 'Psychic'),
#            (371, 'Water', 'Ground'), (372, 'Water', 'Ground'),
#            (373, 'Water', nan), (374, 'Water', 'Dark'),
#            (375, 'Ground', 'Psychic'), (376, 'Ground', 'Psychic'),
#            (377, 'Rock', 'Grass'), (378, 'Rock', 'Grass'),
#            (379, 'Rock', 'Bug'), (380, 'Rock', 'Bug'),
#            (381, 'Water', nan), (382, 'Water', nan), (383, 'Normal', nan),
#            (384, 'Normal', nan), (385, 'Ghost', nan), (386, 'Ghost', nan),
#            (387, 'Ghost', nan), (388, 'Ghost', nan), (389, 'Ghost', nan),
#            (390, 'Grass', 'Flying'), (391, 'Psychic', nan),
#            (392, 'Dark', nan), (393, 'Dark', nan), (394, 'Psychic', nan),
#            (395, 'Ice', nan), (396, 'Ice', nan), (397, 'Ice', nan),
#            (398, 'Ice', 'Water'), (399, 'Ice', 'Water'),
#            (400, 'Ice', 'Water'), (401, 'Water', nan),
#            (402, 'Water', nan), (403, 'Water', nan),
#            (404, 'Water', 'Rock'), (405, 'Water', nan),
#            (406, 'Dragon', nan), (407, 'Dragon', nan),
#            (408, 'Dragon', 'Flying'), (409, 'Dragon', 'Flying'),
#            (410, 'Steel', 'Psychic'), (411, 'Steel', 'Psychic'),
#            (412, 'Steel', 'Psychic'), (413, 'Steel', 'Psychic'),
#            (414, 'Rock', nan), (415, 'Ice', nan), (416, 'Steel', nan),
#            (417, 'Dragon', 'Psychic'), (418, 'Dragon', 'Psychic'),
#            (419, 'Dragon', 'Psychic'), (420, 'Dragon', 'Psychic'),
#            (421, 'Water', nan), (422, 'Water', nan), (423, 'Ground', nan),
#            (424, 'Ground', 'Fire'), (425, 'Dragon', 'Flying'),
#            (426, 'Dragon', 'Flying'), (427, 'Steel', 'Psychic'),
#            (428, 'Psychic', nan), (429, 'Psychic', nan),
#            (430, 'Psychic', nan), (431, 'Psychic', nan),
#            (432, 'Grass', nan), (433, 'Grass', nan),
#            (434, 'Grass', 'Ground'), (435, 'Fire', nan),
#            (436, 'Fire', 'Fighting'), (437, 'Fire', 'Fighting'),
#            (438, 'Water', nan), (439, 'Water', nan),
#            (440, 'Water', 'Steel'), (441, 'Normal', 'Flying'),
#            (442, 'Normal', 'Flying'), (443, 'Normal', 'Flying'),
#            (444, 'Normal', nan), (445, 'Normal', 'Water'),
#            (446, 'Bug', nan), (447, 'Bug', nan), (448, 'Electric', nan),
#            (449, 'Electric', nan), (450, 'Electric', nan),
#            (451, 'Grass', 'Poison'), (452, 'Grass', 'Poison'),
#            (453, 'Rock', nan), (454, 'Rock', nan), (455, 'Rock', 'Steel'),
#            (456, 'Rock', 'Steel'), (457, 'Bug', nan),
#            (458, 'Bug', 'Grass'), (459, 'Bug', 'Ground'),
#            (460, 'Bug', 'Steel'), (461, 'Bug', 'Flying'),
#            (462, 'Bug', 'Flying'), (463, 'Bug', 'Flying'),
#            (464, 'Electric', nan), (465, 'Water', nan),
#            (466, 'Water', nan), (467, 'Grass', nan), (468, 'Grass', nan),
#            (469, 'Water', nan), (470, 'Water', 'Ground'),
#            (471, 'Normal', nan), (472, 'Ghost', 'Flying'),
#            (473, 'Ghost', 'Flying'), (474, 'Normal', nan),
#            (475, 'Normal', nan), (476, 'Normal', 'Fighting'),
#            (477, 'Ghost', nan), (478, 'Dark', 'Flying'),
#            (479, 'Normal', nan), (480, 'Normal', nan),
#            (481, 'Psychic', nan), (482, 'Poison', 'Dark'),
#            (483, 'Poison', 'Dark'), (484, 'Steel', 'Psychic'),
#            (485, 'Steel', 'Psychic'), (486, 'Rock', nan),
#            (487, 'Psychic', 'Fairy'), (488, 'Normal', nan),
#            (489, 'Normal', 'Flying'), (490, 'Ghost', 'Dark'),
#            (491, 'Dragon', 'Ground'), (492, 'Dragon', 'Ground'),
#            (493, 'Dragon', 'Ground'), (494, 'Dragon', 'Ground'),
#            (495, 'Normal', nan), (496, 'Fighting', nan),
#            (497, 'Fighting', 'Steel'), (498, 'Fighting', 'Steel'),
#            (499, 'Ground', nan), (500, 'Ground', nan),
#            (501, 'Poison', 'Bug'), (502, 'Poison', 'Dark'),
#            (503, 'Poison', 'Fighting'), (504, 'Poison', 'Fighting'),
#            (505, 'Grass', nan), (506, 'Water', nan), (507, 'Water', nan),
#            (508, 'Water', 'Flying'), (509, 'Grass', 'Ice'),
#            (510, 'Grass', 'Ice'), (511, 'Grass', 'Ice'),
#            (512, 'Dark', 'Ice'), (513, 'Electric', 'Steel'),
#            (514, 'Normal', nan), (515, 'Ground', 'Rock'),
#            (516, 'Grass', nan), (517, 'Electric', nan),
#            (518, 'Fire', nan), (519, 'Fairy', 'Flying'),
#            (520, 'Bug', 'Flying'), (521, 'Grass', nan), (522, 'Ice', nan),
#            (523, 'Ground', 'Flying'), (524, 'Ice', 'Ground'),
#            (525, 'Normal', nan), (526, 'Psychic', 'Fighting'),
#            (527, 'Psychic', 'Fighting'), (528, 'Rock', 'Steel'),
#            (529, 'Ghost', nan), (530, 'Ice', 'Ghost'),
#            (531, 'Electric', 'Ghost'), (532, 'Electric', 'Fire'),
#            (533, 'Electric', 'Water'), (534, 'Electric', 'Ice'),
#            (535, 'Electric', 'Flying'), (536, 'Electric', 'Grass'),
#            (537, 'Psychic', nan), (538, 'Psychic', nan),
#            (539, 'Psychic', nan), (540, 'Steel', 'Dragon'),
#            (541, 'Water', 'Dragon'), (542, 'Fire', 'Steel'),
#            (543, 'Normal', nan), (544, 'Ghost', 'Dragon'),
#            (545, 'Ghost', 'Dragon'), (546, 'Psychic', nan),
#            (547, 'Water', nan), (548, 'Water', nan), (549, 'Dark', nan),
#            (550, 'Grass', nan), (551, 'Grass', 'Flying'),
#            (552, 'Normal', nan), (553, 'Psychic', 'Fire'),
#            (554, 'Grass', nan), (555, 'Grass', nan), (556, 'Grass', nan),
#            (557, 'Fire', nan), (558, 'Fire', 'Fighting'),
#            (559, 'Fire', 'Fighting'), (560, 'Water', nan),
#            (561, 'Water', nan), (562, 'Water', nan), (563, 'Normal', nan),
#            (564, 'Normal', nan), (565, 'Normal', nan),
#            (566, 'Normal', nan), (567, 'Normal', nan), (568, 'Dark', nan),
#            (569, 'Dark', nan), (570, 'Grass', nan), (571, 'Grass', nan),
#            (572, 'Fire', nan), (573, 'Fire', nan), (574, 'Water', nan),
#            (575, 'Water', nan), (576, 'Psychic', nan),
#            (577, 'Psychic', nan), (578, 'Normal', 'Flying'),
#            (579, 'Normal', 'Flying'), (580, 'Normal', 'Flying'),
#            (581, 'Electric', nan), (582, 'Electric', nan),
#            (583, 'Rock', nan), (584, 'Rock', nan), (585, 'Rock', nan),
#            (586, 'Psychic', 'Flying'), (587, 'Psychic', 'Flying'),
#            (588, 'Ground', nan), (589, 'Ground', 'Steel'),
#            (590, 'Normal', nan), (591, 'Normal', 'Fairy'),
#            (592, 'Fighting', nan), (593, 'Fighting', nan),
#            (594, 'Fighting', nan), (595, 'Water', nan),
#            (596, 'Water', 'Ground'), (597, 'Water', 'Ground'),
#            (598, 'Fighting', nan), (599, 'Fighting', nan),
#            (600, 'Bug', 'Grass'), (601, 'Bug', 'Grass'),
#            (602, 'Bug', 'Grass'), (603, 'Bug', 'Poison'),
#            (604, 'Bug', 'Poison'), (605, 'Bug', 'Poison'),
#            (606, 'Grass', 'Fairy'), (607, 'Grass', 'Fairy'),
#            (608, 'Grass', nan), (609, 'Grass', nan), (610, 'Water', nan),
#            (611, 'Ground', 'Dark'), (612, 'Ground', 'Dark'),
#            (613, 'Ground', 'Dark'), (614, 'Fire', nan),
#            (615, 'Fire', nan), (616, 'Fire', 'Psychic'),
#            (617, 'Grass', nan), (618, 'Bug', 'Rock'),
#            (619, 'Bug', 'Rock'), (620, 'Dark', 'Fighting'),
#            (621, 'Dark', 'Fighting'), (622, 'Psychic', 'Flying'),
#            (623, 'Ghost', nan), (624, 'Ghost', nan),
#            (625, 'Water', 'Rock'), (626, 'Water', 'Rock'),
#            (627, 'Rock', 'Flying'), (628, 'Rock', 'Flying'),
#            (629, 'Poison', nan), (630, 'Poison', nan), (631, 'Dark', nan),
#            (632, 'Dark', nan), (633, 'Normal', nan), (634, 'Normal', nan),
#            (635, 'Psychic', nan), (636, 'Psychic', nan),
#            (637, 'Psychic', nan), (638, 'Psychic', nan),
#            (639, 'Psychic', nan), (640, 'Psychic', nan),
#            (641, 'Water', 'Flying'), (642, 'Water', 'Flying'),
#            (643, 'Ice', nan), (644, 'Ice', nan), (645, 'Ice', nan),
#            (646, 'Normal', 'Grass'), (647, 'Normal', 'Grass'),
#            (648, 'Electric', 'Flying'), (649, 'Bug', nan),
#            (650, 'Bug', 'Steel'), (651, 'Grass', 'Poison'),
#            (652, 'Grass', 'Poison'), (653, 'Water', 'Ghost'),
#            (654, 'Water', 'Ghost'), (655, 'Water', nan),
#            (656, 'Bug', 'Electric'), (657, 'Bug', 'Electric'),
#            (658, 'Grass', 'Steel'), (659, 'Grass', 'Steel'),
#            (660, 'Steel', nan), (661, 'Steel', nan), (662, 'Steel', nan),
#            (663, 'Electric', nan), (664, 'Electric', nan),
#            (665, 'Electric', nan), (666, 'Psychic', nan),
#            (667, 'Psychic', nan), (668, 'Ghost', 'Fire'),
#            (669, 'Ghost', 'Fire'), (670, 'Ghost', 'Fire'),
#            (671, 'Dragon', nan), (672, 'Dragon', nan),
#            (673, 'Dragon', nan), (674, 'Ice', nan), (675, 'Ice', nan),
#            (676, 'Ice', nan), (677, 'Bug', nan), (678, 'Bug', nan),
#            (679, 'Ground', 'Electric'), (680, 'Fighting', nan),
#            (681, 'Fighting', nan), (682, 'Dragon', nan),
#            (683, 'Ground', 'Ghost'), (684, 'Ground', 'Ghost'),
#            (685, 'Dark', 'Steel'), (686, 'Dark', 'Steel'),
#            (687, 'Normal', nan), (688, 'Normal', 'Flying'),
#            (689, 'Normal', 'Flying'), (690, 'Dark', 'Flying'),
#            (691, 'Dark', 'Flying'), (692, 'Fire', nan),
#            (693, 'Bug', 'Steel'), (694, 'Dark', 'Dragon'),
#            (695, 'Dark', 'Dragon'), (696, 'Dark', 'Dragon'),
#            (697, 'Bug', 'Fire'), (698, 'Bug', 'Fire'),
#            (699, 'Steel', 'Fighting'), (700, 'Rock', 'Fighting'),
#            (701, 'Grass', 'Fighting'), (702, 'Flying', nan),
#            (703, 'Flying', nan), (704, 'Electric', 'Flying'),
#            (705, 'Electric', 'Flying'), (706, 'Dragon', 'Fire'),
#            (707, 'Dragon', 'Electric'), (708, 'Ground', 'Flying'),
#            (709, 'Ground', 'Flying'), (710, 'Dragon', 'Ice'),
#            (711, 'Dragon', 'Ice'), (712, 'Dragon', 'Ice'),
#            (713, 'Water', 'Fighting'), (714, 'Water', 'Fighting'),
#            (715, 'Normal', 'Psychic'), (716, 'Normal', 'Fighting'),
#            (717, 'Bug', 'Steel'), (718, 'Grass', nan),
#            (719, 'Grass', nan), (720, 'Grass', 'Fighting'),
#            (721, 'Fire', nan), (722, 'Fire', nan),
#            (723, 'Fire', 'Psychic'), (724, 'Water', nan),
#            (725, 'Water', nan), (726, 'Water', 'Dark'),
#            (727, 'Normal', nan), (728, 'Normal', 'Ground'),
#            (729, 'Normal', 'Flying'), (730, 'Fire', 'Flying'),
#            (731, 'Fire', 'Flying'), (732, 'Bug', nan), (733, 'Bug', nan),
#            (734, 'Bug', 'Flying'), (735, 'Fire', 'Normal'),
#            (736, 'Fire', 'Normal'), (737, 'Fairy', nan),
#            (738, 'Fairy', nan), (739, 'Fairy', nan), (740, 'Grass', nan),
#            (741, 'Grass', nan), (742, 'Fighting', nan),
#            (743, 'Fighting', 'Dark'), (744, 'Normal', nan),
#            (745, 'Psychic', nan), (746, 'Psychic', nan),
#            (747, 'Psychic', nan), (748, 'Steel', 'Ghost'),
#            (749, 'Steel', 'Ghost'), (750, 'Steel', 'Ghost'),
#            (751, 'Steel', 'Ghost'), (752, 'Fairy', nan),
#            (753, 'Fairy', nan), (754, 'Fairy', nan), (755, 'Fairy', nan),
#            (756, 'Dark', 'Psychic'), (757, 'Dark', 'Psychic'),
#            (758, 'Rock', 'Water'), (759, 'Rock', 'Water'),
#            (760, 'Poison', 'Water'), (761, 'Poison', 'Dragon'),
#            (762, 'Water', nan), (763, 'Water', nan),
#            (764, 'Electric', 'Normal'), (765, 'Electric', 'Normal'),
#            (766, 'Rock', 'Dragon'), (767, 'Rock', 'Dragon'),
#            (768, 'Rock', 'Ice'), (769, 'Rock', 'Ice'),
#            (770, 'Fairy', nan), (771, 'Fighting', 'Flying'),
#            (772, 'Electric', 'Fairy'), (773, 'Rock', 'Fairy'),
#            (774, 'Dragon', nan), (775, 'Dragon', nan),
#            (776, 'Dragon', nan), (777, 'Steel', 'Fairy'),
#            (778, 'Ghost', 'Grass'), (779, 'Ghost', 'Grass'),
#            (780, 'Ghost', 'Grass'), (781, 'Ghost', 'Grass'),
#            (782, 'Ghost', 'Grass'), (783, 'Ghost', 'Grass'),
#            (784, 'Ghost', 'Grass'), (785, 'Ghost', 'Grass'),
#            (786, 'Ghost', 'Grass'), (787, 'Ghost', 'Grass'),
#            (788, 'Ice', nan), (789, 'Ice', nan),
#            (790, 'Flying', 'Dragon'), (791, 'Flying', 'Dragon'),
#            (792, 'Fairy', nan), (793, 'Dark', 'Flying'),
#            (794, 'Dragon', 'Ground'), (795, 'Rock', 'Fairy'),
#            (796, 'Rock', 'Fairy'), (797, 'Psychic', 'Ghost'),
#            (798, 'Psychic', 'Dark'), (799, 'Fire', 'Water')],
#           dtype=[('index', '<i8'), ('Type 1', 'O'), ('Type 2', 'O')])

# %% [markdown]
# ### Cleanup `Name` that contain "Mega"
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
def mega(x):
    if bool(re.findall(r'Mega',x)):
        return True
    else:
        return False

# %%
borrar =pokemon[pokemon['Name'].apply(mega)==True].index
borrar
# Out:
# Int64Index([  3,   7,   8,  12,  19,  23,  71,  87, 102, 124, 137, 141, 154,
#             163, 164, 168, 196, 224, 229, 232, 248, 268, 275, 279, 283, 306,
#             327, 329, 333, 336, 339, 349, 354, 366, 387, 393, 397, 409, 413,
#             418, 420, 426, 476, 494, 498, 511, 527, 591, 796],
#            dtype='int64')

# %%
# enter your code here
pokemon.drop(borrar , inplace=True)

# test transformed data

pokemon.head(10)
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 4    4  Charmander   Fire     NaN    309  39      52       43       60
# 5    5  Charmeleon   Fire     NaN    405  58      64       58       80
# 6    6   Charizard   Fire  Flying    534  78      84       78      109
# 9    7    Squirtle  Water     NaN    314  44      48       65       50
# 10   8   Wartortle  Water     NaN    405  59      63       80       65
# 11   9   Blastoise  Water     NaN    530  79      83      100       85
# 13  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 4        50     65           1      False
# 5        65     80           1      False
# 6        85    100           1      False
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 13       20     45           1      False

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
pokemon['A/D']=pokemon['Attack']/pokemon['Defense']

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio`

# %%
# enter your code here
pokemon[(pokemon['A/D'] == pokemon['A/D'].max())]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D
# 429      180       20    150           3       True  9.0

# %% [markdown]
# ### Identify the pokemon with the lowest A/D Ratio

# %%
# enter your code here
pokemon[(pokemon['A/D'] == pokemon['A/D'].min())]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary       A/D
# 230      5           2      False  0.043478

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# enter your code here
pokemon['Combo_Type']=np.where(pokemon['Type 2'].isnull()==True, pokemon['Type 1'], pokemon['Type 1']+'-'+pokemon['Type 2'])

# %%
pokemon['Combo_Type']
# Out:
# 0       Grass-Poison
# 1       Grass-Poison
# 2       Grass-Poison
# 4               Fire
# 5               Fire
#            ...
# 794    Dragon-Ground
# 795       Rock-Fairy
# 797    Psychic-Ghost
# 798     Psychic-Dark
# 799       Fire-Water
# Name: Combo_Type, Length: 751, dtype: object

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %%
# enter your code here
top5 = pokemon.sort_values('A/D',ascending=False).head(5)
top5
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
# 347  318            Carvanha    Water   Dark    305  45      90       20
# 453  408            Cranidos     Rock    NaN    350  67     125       40
# 348  319            Sharpedo    Water   Dark    460  70     120       40
# 428  386  DeoxysNormal Forme  Psychic    NaN    600  50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary    A/D  Combo_Type
# 429      180       20    150           3       True  9.000     Psychic
# 347       65       20     65           3      False  4.500  Water-Dark
# 453       30       30     58           4      False  3.125        Rock
# 348       95       40     95           3      False  3.000  Water-Dark
# 428      150       50    150           3       True  3.000     Psychic

# %% [markdown]
# ### For the 5 pokemons printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemons with the highest `A/D Ratio`.

# %%
top5['Combo_Type'].unique()
# Out:
# array(['Psychic', 'Water-Dark', 'Rock'], dtype=object)

# %%
# enter your code here
listaCombo=list(top5['Combo_Type'].unique())
listaCombo
# Out:
# ['Psychic', 'Water-Dark', 'Rock']

# %% [markdown]
# ### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.
#
# Your output should look like below:
#
# ![Aggregate](aggregated-mean.png)

# %%
# enter your code here
top5.groupby('Combo_Type').agg(['mean'])
# Out:
#                 #  Total    HP Attack Defense Sp. Atk Sp. Def Speed  \
#              mean   mean  mean   mean    mean    mean    mean  mean
# Combo_Type
# Psychic     386.0  600.0  50.0    165      35     165      35   150
# Rock        408.0  350.0  67.0    125      40      30      30    58
# Water-Dark  318.5  382.5  57.5    105      30      80      30    80
#
#            Generation Legendary    A/D
#                  mean      mean   mean
# Combo_Type
# Psychic             3      True  6.000
# Rock                4     False  3.125
# Water-Dark          3     False  3.750
