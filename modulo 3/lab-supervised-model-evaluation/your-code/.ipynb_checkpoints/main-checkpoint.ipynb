# %% [markdown]
# # Supervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of supervised learning model evaluation.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Regression Model Evaluation

# %%
from sklearn.datasets import load_boston

data = load_boston()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.DataFrame(data["target"], columns=['MEDV'])

boston = pd.concat([X, y], axis=1)

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# ## 1. Split this data set into training (80%) and testing (20%) sets.
#
# The `MEDV` field represents the median value of owner-occupied homes (in $1000's) and is the target variable that we will want to predict.

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test, y_train, y_test = tts(boston.drop('MEDV', axis=1),boston['MEDV'])

# %% [markdown]
# ## 2. Train a `LinearRegression` model on this data set and generate predictions on both the training and the testing set.

# %%
from sklearn.linear_model import LinearRegression as LinReg

# %%
linreg = LinReg()# Se asinga el modelo a una variable

# %%
linreg.fit(x_train,y_train) # Se entrena el modelo con x_Train y y_train
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test) #Se hace la prediccion con x_test
y_pred2=linreg.predict(x_train)

# %% [markdown]
# ## 3. Calculate and print R-squared for both the training and the testing set.

# %%
from sklearn.metrics import r2_score as r2

r2(y_test, y_pred)
# Out:
# 0.7129724835451775

# %%
r2(y_train, y_pred2)
# Out:
# 0.7456939018956403

# %% [markdown]
# ## 4. Calculate and print mean squared error for both the training and the testing set.

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 25.47319611804678

# %%
mean_squared_error(y_train, y_pred2)
# Out:
# 21.09900216716149

# %% [markdown]
# ## 5. Calculate and print mean absolute error for both the training and the testing set.

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 3.4095089883727328

# %%
mean_absolute_error(y_train, y_pred2)
# Out:
# 3.3658275125254304

# %% [markdown]
# ## Classification Model Evaluation

# %%
from sklearn.datasets import load_iris

data = load_iris()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.DataFrame(data["target"], columns=["class"])

iris = pd.concat([X, y], axis=1)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 0        0
# ...

# %% [markdown]
# ## 6. Split this data set into training (80%) and testing (20%) sets.
#
# The `class` field represents the type of flower and is the target variable that we will want to predict.

# %%
x_train,x_test, y_train, y_test = tts(iris.drop('class', axis=1),iris['class'])

# %% [markdown]
# ## 7. Train a `LogisticRegression` model on this data set and generate predictions on both the training and the testing set.

# %%
from sklearn.linear_model import LogisticRegression
logit_reg = LogisticRegression()
logit_fit = logit_reg.fit(x_train,y_train)
y_pred = logit_fit.predict(x_test)
y_pred2 = logit_fit.predict(x_train)

# %% [markdown]
# ## 8. Calculate and print the accuracy score for both the training and the testing set.

# %%
from sklearn.metrics import accuracy_score as acc

acc(y_test, y_pred)
# Out:
# 0.8947368421052632

# %%
acc(y_train, y_pred2)
# Out:
# 0.9821428571428571

# %% [markdown]
# ## 9. Calculate and print the balanced accuracy score for both the training and the testing set.

# %%
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %% [markdown]
# ## 10. Calculate and print the precision score for both the training and the testing set.

# %%
from sklearn.metrics import precision_score as prec

prec(y_test, y_pred, average='macro')
# Out:
# 0.9814814814814815

# %% [markdown]
# ## 11. Calculate and print the recall score for both the training and the testing set.

# %%
from sklearn.metrics import recall_score as rec

rec(y_test, y_pred, average='macro')
# Out:
# 0.9166666666666666

# %%
rec(y_train, y_pred2, average='macro')
# Out:
# 0.9803921568627452

# %% [markdown]
# ## 12. Calculate and print the F1 score for both the training and the testing set.

# %%
from sklearn.metrics import f1_score as f1

f1(y_test, y_pred, average='macro')
# Out:
# 0.8917748917748917

# %%
f1(y_train, y_pred2, average='macro')
# Out:
# 0.981962481962482

# %% [markdown]
# ## 13. Generate confusion matrices for both the training and the testing set.

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  1,  9]])

# %%
confusion_matrix(y_train, y_pred2)
# Out:
# array([[37,  0,  0],
#        [ 0, 41,  0],
#        [ 0,  2, 32]])

# %% [markdown]
# ## Bonus: For each of the data sets in this lab, try training with some of the other models you have learned about, recalculate the evaluation metrics, and compare to determine which models perform best on each data set.

# %%
#funcion clase de hoy
import re
def modeling_testing(lista_modelos, data, target):
    X_train, X_test, y_train, y_test = tts(data.loc[:, data.columns != target], data[target])
    #importo
    from sklearn.metrics import accuracy_score as acc
    from sklearn.metrics import balanced_accuracy_score
    from sklearn.metrics import precision_score as prec
    from sklearn.metrics import recall_score as rec
    from sklearn.metrics import f1_score as f1
    from sklearn.metrics import confusion_matrix
    
    for i in lista_modelos:
        modelo = i()
        modelo.fit(X_train, y_train)
        y_pred = modelo.predict(X_test)
        #pruebas de la clase 
        balance_acc =balanced_accuracy_score(y_test, y_pred)
        accuracy = acc(y_test, y_pred)
        precision_score =prec(y_test, y_pred, average='macro')
        recall_score = rec(y_test, y_pred, average='macro')
        funo= f1(y_test, y_pred, average='macro')
        matriz = confusion_matrix(y_test, y_pred)
       
        
        print('Modelo:',re.findall(r'\b(\w+)\b\'\>',str(i))[0])
        print('balance accuracy:', balance_acc,'\naccuracy:',accuracy,'\nPrecision score',precision_score,'\nrecall score',
             recall_score,'\nf1',funo,'\nmatriz=\n',matriz, '\n')

# %%
#importo modelos de clasifcación
from sklearn.linear_model import SGDClassifier as SGDC
from sklearn.linear_model import LogisticRegression as logreg
from sklearn.neighbors import KNeighborsClassifier as KNNC
from sklearn.naive_bayes import GaussianNB as GNB #Bayes para regresion 
from sklearn.naive_bayes import MultinomialNB as MNB #Bayes con variables discretas (categoricas)
from sklearn.naive_bayes import ComplementNB as CNB
from sklearn.naive_bayes import BernoulliNB as BNB
from catboost import CatBoostClassifier as CATB

# %%
#para iris
modelos1 = [SGDC, KNNC, GNB,MNB,CNB,BNB,CATB]

modeling_testing(modelos1, iris,'class' )
# Out:
# Modelo: SGDClassifier
# balance accuracy: 0.9209401709401709
# accuracy: 0.9210526315789473
# Precision score 0.9206349206349206
# recall score 0.9209401709401709
# f1 0.9198765432098766
# matriz=
#  [[13  0  0]
#  [ 1 11  1]
#  [ 0  1 11]]
#
# Modelo: KNeighborsClassifier
# balance accuracy: 0.9743589743589745
# accuracy: 0.9736842105263158
# Precision score 0.9743589743589745
# recall score 0.9743589743589745
# f1 0.9733333333333333
# matriz=
#  [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
#
# Modelo: GaussianNB
# balance accuracy: 0.9743589743589745
# accuracy: 0.9736842105263158
# Precision score 0.9743589743589745
# recall score 0.9743589743589745
# f1 0.9733333333333333
# matriz=
#  [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
#
# Modelo: MultinomialNB
# balance accuracy: 0.9465811965811967
# accuracy: 0.9473684210526315
# Precision score 0.9465811965811967
# recall score 0.9465811965811967
# f1 0.9465811965811967
# matriz=
#  [[13  0  0]
#  [ 0 12  1]
#  [ 0  1 11]]
#
# ...

# %%
'''Para iris buenos modelos serían : linreg, Catboost, MultinominlNB, gaussianNB, kNeighbors y SGDClassifier'''
# Out:
# 'Para iris buenos modelos serían : linreg, Catboost, MultinominlNB, gaussianNB, kNeighbors y SGDClassifier'

# %%
#librerias boston para regresion
from statsmodels.regression.linear_model import OLS
from sklearn.linear_model import LinearRegression as LinReg
import statsmodels.api as sm

# %%
#No funcionó la funcion para boston

x_train,x_test, y_train, y_test = tts(boston.drop('MEDV', axis=1),boston['MEDV'])

# %%
X = sm.add_constant(x_train)
modelo = OLS(y_train,X).fit()

# %%
y_pred = modelo.predict(sm.add_constant(x_test))

# %%
r2(y_test, y_pred)
# Out:
# 0.7276743671511059

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 26.616108146333456

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 3.1818226654483217

# %%
''' Para boston son similares los modelos linreg y OLS'''
# Out:
# ' Para boston son similares los modelos linreg y OLS'
