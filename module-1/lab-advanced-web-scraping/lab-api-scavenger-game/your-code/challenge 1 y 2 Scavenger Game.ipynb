# %%
from github import Github
import requests

import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
g = Github("15f73a5eae770b0efdd4ddf82f0eacbbca305ad6")

# %%
repo = g.get_repo("ironhack-datalabs/madrid-oct-2018")

# %%
resp = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks')
json1 = resp.json()

# %%
data = pd.DataFrame(json1)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-685e815568f2> in <module>
# ----> 1 data = pd.DataFrame(json1)
#       2 data
#
# NameError: name 'json1' is not defined

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 73 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 16 non-null     int64
#  1   node_id            16 non-null     object
#  2   name               16 non-null     object
#  3   full_name          16 non-null     object
#  4   private            16 non-null     bool
#  5   owner              16 non-null     object
#  6   html_url           16 non-null     object
#  7   description        8 non-null      object
#  8   fork               16 non-null     bool
#  9   url                16 non-null     object
#  10  forks_url          16 non-null     object
#  11  keys_url           16 non-null     object
#  12  collaborators_url  16 non-null     object
#  13  teams_url          16 non-null     object
#  14  hooks_url          16 non-null     object
#  15  issue_events_url   16 non-null     object
# ...

# %%
#todos los forks

data['full_name'].value_counts()
# Out:
# pablobarrio/madrid-oct-2018           1
# lmartinezruizit/datamad0119           1
# eye8/madrid-oct-2018                  1
# ToniPons97/mad-oct-2018               1
# criraca/madrid-oct-2018               1
# nancyulric/mad-oct-2018               1
# miriammg/madrid-oct-2018              1
# albertogcmr/madrid-oct-2018           1
# rsennes/mad-oct-2018                  1
# gggfaria/mad-oct-2018                 1
# AlbertoCastellanos/madrid-oct-2018    1
# Spurda/mad-oct-2018                   1
# elenajpp/madrid-oct-2018              1
# marisfont/madrid-oct-2018             1
# ArieHassan/madrid-oct-2018            1
# cmvalma/madrid-oct-2018               1
# Name: full_name, dtype: int64

# %%
#lenguajes
data['language'].value_counts()
# Out:
# Jupyter Notebook    13
# HTML                 1
# Name: language, dtype: int64

# %% [markdown]
# Challenge 2

# %%
resp2 = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/stats/commit_activity')
json2 = resp2.json()
data2 = pd.DataFrame(json2)
data2
# Out:
#     total        week                   days
# 0       0  1567296000  [0, 0, 0, 0, 0, 0, 0]
# 1       0  1567900800  [0, 0, 0, 0, 0, 0, 0]
# 2       0  1568505600  [0, 0, 0, 0, 0, 0, 0]
# 3       0  1569110400  [0, 0, 0, 0, 0, 0, 0]
# 4       0  1569715200  [0, 0, 0, 0, 0, 0, 0]
# 5       0  1570320000  [0, 0, 0, 0, 0, 0, 0]
# 6       0  1570924800  [0, 0, 0, 0, 0, 0, 0]
# 7       0  1571529600  [0, 0, 0, 0, 0, 0, 0]
# 8       0  1572134400  [0, 0, 0, 0, 0, 0, 0]
# 9       0  1572739200  [0, 0, 0, 0, 0, 0, 0]
# 10      0  1573344000  [0, 0, 0, 0, 0, 0, 0]
# 11      0  1573948800  [0, 0, 0, 0, 0, 0, 0]
# 12      0  1574553600  [0, 0, 0, 0, 0, 0, 0]
# 13      0  1575158400  [0, 0, 0, 0, 0, 0, 0]
# 14      0  1575763200  [0, 0, 0, 0, 0, 0, 0]
# 15      0  1576368000  [0, 0, 0, 0, 0, 0, 0]
# 16      0  1576972800  [0, 0, 0, 0, 0, 0, 0]
# 17      0  1577577600  [0, 0, 0, 0, 0, 0, 0]
# 18      0  1578182400  [0, 0, 0, 0, 0, 0, 0]
# 19      0  1578787200  [0, 0, 0, 0, 0, 0, 0]
# ...

# %%
data2['total'].value_counts() #cero commits
# Out:
# 0    52
# Name: total, dtype: int64
