# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/rube/datamex_082020/module-1/pandas-project/your-code/attacks.csv', engine = 'python', sep=',')

# %%
data.shape
# Out:
# (25723, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
null_cols = data.isnull().sum()
print(null_cols)
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
data['Unnamed: 22'].notnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25718    False
# 25719    False
# 25720    False
# 25721    False
# 25722    False
# Name: Unnamed: 22, Length: 25723, dtype: bool

# %%
data.loc[data['Unnamed: 22'].notnull()]
# Out:
#      Case Number         Date    Year        Type Country    Area  \
# 1478  2006.05.27  27-May-2006  2006.0  Unprovoked     USA  Hawaii
#
#                 Location Activity          Name Sex   ... Species   \
# 1478  North Shore, O'ahu  Surfing  Bret Desmond    M  ...      NaN
#
#      Investigator or Source                     pdf  \
# 1478             R. Collier  2006.05.27-Desmond.pdf
#
#                                            href formula  \
# 1478  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1478  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.05.27
#
#      Case Number.2 original order   Unnamed: 22 Unnamed: 23
# 1478    2006.05.27         4825.0  stopped here         NaN
#
# [1 rows x 24 columns]

# %%
data.loc[data['Unnamed: 23'].notnull()]
# Out:
#        Case Number                  Date    Year        Type  \
# 4415    1952.03.30           30-Mar-1952  1952.0  Unprovoked
# 5840  1878.09.14.R  Reported 14-Sep-1878  1878.0    Provoked
#
#                    Country         Area                    Location  \
# 4415  NETHERLANDS ANTILLES      Curacao                         NaN
# 5840                   USA  Connecticut  Branford, New Haven County
#
#                                              Activity              Name Sex   \
# 4415  Went to aid of child being menaced by the shark       A.J. Eggink    M
# 5840                                          Fishing  Captain Pattison    M
#
#       ...                                           Species   \
# 4415  ...  Bull shark, 2.7 m [9'] was captured & dragged ...
# 5840  ...                                                NaN
#
#                                  Investigator or Source  \
# 4415  J. Randall, p.352 in Sharks & Survival; H.D. B...
# ...

# %%
'''The values where columns Unnamed 22 and Unnamed 23 ara not nules have no sense, so they can be dropped'''
# Out:
# 'The values where columns Unnamed 22 and Unnamed 23 ara not nules have no sense, so they can be dropped'

# %%
data1 = data.drop(['Unnamed: 22', 'Unnamed: 23'], axis =1)

# %%
data1.isnull()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
data.loc[data['Case Number'].isnull()]
# Out:
#       Case Number                  Date    Year      Type Country     Area  \
# 5488          NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida
# 8702          NaN                   NaN     NaN       NaN     NaN      NaN
# 8703          NaN                   NaN     NaN       NaN     NaN      NaN
# 8704          NaN                   NaN     NaN       NaN     NaN      NaN
# 8705          NaN                   NaN     NaN       NaN     NaN      NaN
# ...           ...                   ...     ...       ...     ...      ...
# 25717         NaN                   NaN     NaN       NaN     NaN      NaN
# 25718         NaN                   NaN     NaN       NaN     NaN      NaN
# 25719         NaN                   NaN     NaN       NaN     NaN      NaN
# 25720         NaN                   NaN     NaN       NaN     NaN      NaN
# 25721         NaN                   NaN     NaN       NaN     NaN      NaN
#
# ...

# %%
data1.iloc[8702:]
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8703          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8704          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8705          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8706          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
# ...

# %%
"From line 8702, plenty of the data is nule"

data2 = data1.drop(range(8702,25723), axis = 0)

# %%
data2.loc[data2['Case Number'] == '0']
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 8697           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Fatal (Y/N) Time Species  Investigator or Source  pdf href formula  \
# ...

# %%
data2.loc[data2['original order'].isnull()]
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6309           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6310           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6311           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6312           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6313           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 8697           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Fatal (Y/N) Time Species  Investigator or Source  pdf href formula  \
# ...

# %%
#Deleting Cero and nule rows

data3 = data2.drop(range(6302,8702), axis = 0)

# %%
data3
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
data3['Type'].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
data3['Type'] = data3['Type'].str.replace('Boating', 'Boat')
data3['Type'] = data3['Type'].str.replace('Boatomg', 'Boat')

# %%
data3['Type'].value_counts() #goodone
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Boat             341
# Sea Disaster     239
# Questionable       2
# Name: Type, dtype: int64

# %%
data3.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
data3['Year'].value_counts() #good one
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1801.0      1
# 1638.0      1
# 1834.0      1
# 1723.0      1
# 1786.0      1
# Name: Year, Length: 249, dtype: int64

# %%
data3['Age'].value_counts()
# Out:
# 17         154
# 18         150
# 19         142
# 20         141
# 15         139
#           ...
# 34 & 19      1
# 60s          1
#  43          1
# 46 & 34      1
#  30          1
# Name: Age, Length: 157, dtype: int64

# %%
#defining useful columns:

data4 = data3[['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
       'Species ', 'Investigator or Source']]

# %%
#función para actividad
def activity(x):
    try:
        y = x.split()
        for z in y:
            if z.endswith('ing'):
                return z
    except:
        pass

# %%
a = 'just having fun'

# %%
data4['Activity'].astype(str)
# Out:
# 0           Paddling
# 1           Standing
# 2            Surfing
# 3            Surfing
# 4        Free diving
#             ...
# 6297          Diving
# 6298    Pearl diving
# 6299        Swimming
# 6300             nan
# 6301        Swimming
# Name: Activity, Length: 6302, dtype: object

# %%
data4['good Activity'] = data4['Activity'].apply(activity) #resume las actividades
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data4['Type'].value_counts() #good column
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Boat             341
# Sea Disaster     239
# Questionable       2
# Name: Type, dtype: int64

# %%
data4['Year'].value_counts() #good column
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1801.0      1
# 1638.0      1
# 1834.0      1
# 1723.0      1
# 1786.0      1
# Name: Year, Length: 249, dtype: int64

# %%
data4['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
#fixing country
data4['Country'] = data4['Country'].str.replace('UNITED ARAB EMIRATES', 'UNITED ARAB EMIRATES (UAE)')
data4['Country'] = data4['Country'].str.replace('OKINAWA', 'JAPAN')
data4['Country'] = data4['Country'].str.replace('BRITISH ISLES', 'UNITED KINGDOM')
data4['Country'] = data4['Country'].str.replace('CEYLON', 'CEYLON (SRI LANKA)')
data4['Country'] = data4['Country'].str.replace('?', '')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data4['sex']=data4['Sex '] 
data4['sex'].value_counts() #we can ommit the invalid values in the analysis
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# M      5094
# F       637
# N         2
# M         2
# .         1
# lli       1
# Name: sex, dtype: int64

# %%
#cleaning Age
data4['Age'].value_counts()
# Out:
# 17         154
# 18         150
# 19         142
# 20         141
# 15         139
#           ...
# 34 & 19      1
# 60s          1
#  43          1
# 46 & 34      1
#  30          1
# Name: Age, Length: 157, dtype: int64

# %%
def age(x):
    try:
        y = x.split()
        for i in y:
            if i.isnumeric():
                return float(i)
    except:
        return x

# %%
data4['age'] = data4['Age'].apply(age)
data4['age'].unique()
# Out:
# array([57., 11., 48., nan, 18., 52., 15., 12., 32., 10., 21., 34., 30.,
#        60., 33., 29., 54., 41., 37., 56., 19., 25., 69., 38., 55., 35.,
#        46., 45., 14., 28., 20., 24., 26., 49., 22.,  7., 31., 17., 40.,
#        13., 42.,  3.,  8., 50., 16., 82., 73., 68., 51., 39., 58., 47.,
#        61., 65., 36., 66., 43.,  9., 72., 59.,  6., 27., 64., 23., 71.,
#        44., 62., 63., 70., 53., 77., 74.,  5., 86., 84., 75., 87., 67.,
#         1.,  2., 81., 78.])

# %%
data4['age'].isnull().value_counts()
#40% on average of the age values are null, It cannot be filled or dropped
# Out:
# False    3414
# True     2888
# Name: age, dtype: int64

# %%
#analazyn data
data4['nage']=pd.to_numeric(data4['age'])
data4['nage'].describe()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# count    3414.00000
# mean       27.29174
# std        13.89131
# min         1.00000
# 25%        17.00000
# 50%        24.00000
# 75%        35.00000
# max        87.00000
# Name: nage, dtype: float64

# %%
data4['Injury'].isnull().value_counts() #only 28 missing
# Out:
# False    6274
# True       28
# Name: Injury, dtype: int64

# %%
data4['Injury'].unique #this column is so disperse to be analyzed
# Out:
# <bound method Series.unique of 0       No injury to occupant, outrigger canoe and pad...
# 1                              Minor injury to left thigh
# 2            Injury to left lower leg from surfboard skeg
# 3                               Minor injury to lower leg
# 4       Lacerations to leg & hand shark PROVOKED INCIDENT
#                               ...
# 6297                                                FATAL
# 6298                                                FATAL
# 6299                                                FATAL
# 6300                                                FATAL
# 6301    FATAL. "Shark bit him in half, carrying away t...
# Name: Injury, Length: 6302, dtype: object>

# %%
data4['Fatal (Y/N)'].value_counts()
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %%
data4['fatal'] = data4['Fatal (Y/N)'].str.replace('2017', 'UNKNOWN')
data4['fatal'] = data4['fatal'].str.replace(' N', 'N')
data4['fatal'] = data4['fatal'].str.replace('M', 'N')
data4['fatal'] = data4['fatal'].str.replace('y', 'Y')
data4['fatal'] = data4['fatal'].str.replace('N ', 'N')

# %%
data4['fatal'].value_counts() #good Column
# Out:
# N          4302
# Y          1389
# UNKNOWN      72
# Name: fatal, dtype: int64

# %%
data4['Species '].isnull().value_counts() # arround 40% of the species are null
# Out:
# False    3464
# True     2838
# Name: Species , dtype: int64

# %%
data4['Species '].value_counts() #colum so dispersed
# Out:
# White shark                                                          163
# Shark involvement prior to death was not confirmed                   105
# Invalid                                                              102
# Shark involvement not confirmed                                       88
# Tiger shark                                                           73
#                                                                     ...
# 4 m to 5 m [13' to 16.5']  white shark                                 1
# 3 m, 600-kg shark                                                      1
# Blacktip shark, 1.2 m to 1.8 m [4' to 6']                              1
# White shark, 160-kg [353-lb], identity confirmed by tooth pattern      1
# Shark involvement prior to death remains unconfirmed                   1
# Name: Species , Length: 1549, dtype: int64

# %%
data4['Time'].isnull().value_counts()
# Out:
# True     3354
# False    2948
# Name: Time, dtype: int64

# %%
data4['Time'].value_counts()
# Out:
# Afternoon         187
# 11h00             128
# Morning           121
# 12h00             109
# 15h00             108
#                  ...
# 06h00 -- 07h00      1
# 09h00 -10h00        1
# 13h10               1
# 15h00 or 15h45      1
# 19h10               1
# Name: Time, Length: 366, dtype: int64

# %%
data['Time'].unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', nan, 'Late afternoon', '17h00',
#        '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30', '10h40',
#        '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40', '08h00',
#        '17h35', '15h30', '07h30', '19h00, Dusk', 'Night', '16h00',
#        '15h01', '12h00', '13h45', '23h30', '09h00', '14h30', '18h30',
#        '12h30', '16h30', '18h45', '06h00', '10h00', '10h44', '13h19',
#        'Midday', '13h30', '10h45', '11h20', '11h45', '19h30', '08h30',
#        '15h45', 'Shortly before 12h00', '17h34', '17h10', '11h15',
#        '08h50', '17h45', '13h00', '10h20', '13h20', '02h00', '09h50',
#        '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15', '15h40',
#        '19h05', '1300', '14h30 / 15h30', '22h00', '16h20', '14h34',
#        '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
# ...

# %%
def time (x):
    try:
        if x.startswith(('06','07','08','09','10','11','Shortly before', 'Early', 'A.M.', 'Just', 'Daytime', 'AM')):
            y ='Morning'
            return y
        elif x.startswith(('12','13','14','15','16','17','18', '19', 'Mid','Sunset', 'Eve','Late','After', 'P.M.','noon', 'Lunch', 'Dawn' )):
            y = 'Afternoon'
            return y
        elif x.startswith(('2','00','01','02','03','04','05','Dusk', 'Dark','dusk','night', '"Night"')):
            y = 'Night'
            return y
        else:
            return x
    except:
        return x

# %%
data4['time'] = data4['Time'].apply(time)

# %%
data4['time'].value_counts() #we can ommit vale 1 data
# Out:
# Afternoon                                                                1802
# Morning                                                                   931
# Night                                                                     171
# --                                                                          5
#                                                                             2
# >14h30                                                                      1
# Shortly after midnight                                                      1
# �                                                                           1
# "Evening"                                                                   1
# Before daybreak                                                             1
# Prior to 10h37                                                              1
# >08h00                                                                      1
# ...

# %%
data4.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'good Activity', 'sex', 'age',
#        'nage', 'time', 'fatal'],
#       dtype='object')

# %%
data4['Type'].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Boat             341
# Sea Disaster     239
# Questionable       2
# Name: Type, dtype: int64

# %%
data5 = data4[['Case Number', 'Year', 'Type','time','Country', 'good Activity', 'sex', 'age', 'fatal']]

# %%
data5.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'time', 'Country', 'good Activity',
#        'sex', 'age', 'fatal'],
#       dtype='object')

# %%
data5 = data5.rename(columns = {'good Activity': 'Activity'})

# %%
data5.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'time', 'Country', 'Type', 'Activity',
#        'sex', 'age', 'fatal'],
#       dtype='object')

# %% [markdown]
# Exportando el csv

# %%
data_csv = data5.to_csv('/Users/rube/datamex_082020/module-1/pandas-project/your-code/sharks.csv',sep=',', index=False)

# %% [markdown]
# # Bullet points

# %%
data5.shape
# Out:
# (6302, 11)

# %%
data5.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'time', 'Country', 'good Activity',
#        'sex', 'age', 'fatal'],
#       dtype='object')

# %%
data5['Type'].value_counts().plot(kind = 'pie')
#arroud 3/4 of the acttakcs were unprovoked
# Out:
# <AxesSubplot:ylabel='Type'>

# %%
data5['Year'].value_counts().plot(x='Year');

# %%
data['Year'].value_counts() #attacks are incrasing through time mainly after 2015
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1753.0      1
# 77.0        1
# 1785.0      1
# 1580.0      1
# 1543.0      1
# Name: Year, Length: 249, dtype: int64

# %%
data5['Country'].value_counts().plot(kind = 'pie')
#arround 60% of the attacks are in three countries: USA, Australia and South Africa
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
data5['Activity'].value_counts().plot(kind = 'pie')
# Out:
# '3/4 of the attaks are not fatal'

# %%
data5['Activity'].value_counts() #3/4 of the activities were acuatic activities
# Out:
# Swimming        1052
# Surfing         1005
# Fishing          584
# Spearfishing     384
# diving           269
#                 ...
# Examining          1
# Angling            1
# Foundering         1
# throwing           1
# Bringing           1
# Name: Activity, Length: 277, dtype: int64

# %%
data5['fatal'].value_counts().plot(kind = 'pie')
'''3/4 of the attaks are not fatal'''
# Out:
# '3/4 of the attaks are not fatal'

# %%
data5['age'].value_counts().plot(kind = 'bar')

#mayority of teh atacks are on young people
# Out:
# <AxesSubplot:>

# %%
data5['age'].describe()
# Out:
# count    3414.00000
# mean       27.29174
# std        13.89131
# min         1.00000
# 25%        17.00000
# 50%        24.00000
# 75%        35.00000
# max        87.00000
# Name: age, dtype: float64

# %%
data5['sex'].value_counts().plot(kind = 'pie')
'''Mayority of attacks are on men arround 80%'''
# Out:
# 'Mayority of attacks are on men arround 80%'

# %%
data5['time'].value_counts().plot(kind = 'pie')
#''arround 60% of the attacks are on the afternoon''
# Out:
# <AxesSubplot:ylabel='time'>
